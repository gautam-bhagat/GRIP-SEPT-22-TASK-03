# %% [markdown]
# <br><br><br>
# # <b>THE SPARKS FOUNDATION </b>
# ##### <B>DATA SCIENCE & BUSINESS  ANALYTICS</B>
# #### <i> GRIP SEPTEMBER 2022</i>
# <B>TASK #03 : EXPLORATORY DATA ANALYSIS : RETAIL<Br><BR></B>
# DESCRIPTION :<U>Perform EDA on dataset "SampleSuperstore"</U><BR>
# EXECUTED BY : <B>GAUTAM BHAGAT</B><br><br><br>

# %% [markdown]
# <b>Dataset : https://bit.ly/3L2DSkx </b>

# %% [markdown]
# ### <b>Importing Required Libraries</b>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings as wg
wg.filterwarnings('ignore')

# %% [markdown]
# #### <b>Reading Dataset</b>

# %%
data = pd.read_csv("samplesuperstore.csv")
data.head(10)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# ...

# %% [markdown]
# #### <b>Data Preprocessing</b>

# %%
data.shape
# Out:
# (9994, 13)

# %%
data.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
data.drop('Postal Code',inplace=True,axis=1)

# %%
data.duplicated().sum()
# Out:
# 50

# %%
data.drop_duplicates()
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#   Region         Category Sub-Category     Sales  Quantity  Discount    Profit
# 0  South        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1  South        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2   West  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3  South        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  South  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %% [markdown]
# ### <b>Exploratory Data Analysis</b>

# %% [markdown]
# ### Pairplotting different combinations

# %%
sns.pairplot(data)

# %% [markdown]
# #### Co-Relation via Heat-Map

# %%
data.corr()
plt.figure(figsize=(8,6))
sns.heatmap(data.corr(),annot=True)
plt.show()

# %% [markdown]
# #### Visualizing in terms of Category

# %%
plt.figure(figsize=(4,5))
textprops={"fontsize":17}
plt.title("Category")
plt.pie(data['Category'].value_counts(),labels=data['Category'].value_counts().index,autopct='%1.1f%%',textprops=textprops)
plt.show()

# %% [markdown]
# #### Sales v/s Profit (Category wise)

# %%
plt.figure(figsize=(10,8))
data.groupby('Category')['Profit','Sales'].agg(['sum']).plot.bar()
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# #### Sales v/s Profit (Sub-Category wise)

# %%
top_subcategory_sales = data.groupby("Sub-Category").Sales.sum().nlargest(n=100)

top_subcategory_profit = data.groupby("Sub-Category").Profit.sum().nlargest(n=100)
plt.style.use('seaborn')
top_subcategory_sales.plot(kind='bar',figsize=(10,8),fontsize=15)
top_subcategory_profit.plot(kind='bar',figsize=(10,8),fontsize=15,color='green')
plt.xlabel('Sub-Category')
plt.ylabel('Total Sales & Profit')
plt.title('Top Sub-Category Sales v/s Profit')
plt.show()

# %% [markdown]
# #### Profit in terms of Sub-Category

# %%
plt.figure(figsize=(10,8))
category_wise_profit=data.groupby(['Sub-Category'])['Profit'].sum().nlargest(50)
category_wise_profit.plot.barh()
# Out:
# <AxesSubplot:ylabel='Sub-Category'>

# %% [markdown]
# #### Discount v/s Profit

# %%
plt.figure(figsize=(10,8))
sns.lineplot(data['Discount'],data['Profit'],data=data)
# Out:
# <AxesSubplot:xlabel='Discount', ylabel='Profit'>

# %% [markdown]
# #### Region wise Sales

# %%
plt.figure(figsize=(5,5))
plt.title("Region")
plt.pie(data['Region'].value_counts(),labels=data['Region'].value_counts().index,autopct="%1.1f%%")
plt.show()

# %% [markdown]
# #### Sales v/s Profit (State wise)

# %%
top_state_sales = data.groupby("State").Sales.sum().nlargest(n=10)
top_state_profit = data.groupby("State").Profit.sum().nlargest(n=10)

plt.style.use('seaborn')
top_state_sales.plot(kind='bar',figsize=(10,8),fontsize=15)
top_state_profit.plot(kind='bar',figsize=(10,8),fontsize=15,color='green')
plt.xlabel('State')
plt.ylabel('Total Sales & Profit')
plt.title('Top States Sales v/s Profit')
plt.show()

# %% [markdown]
# #### Interdependency of Sales,Profits and Discounts

# %%
plt.style.use('seaborn')
data.plot(kind='scatter',figsize=(10,6),x='Sales',y='Profit',c='Discount',s=20,fontsize=14,colormap='viridis')
plt.ylabel('Total Profits',fontsize=15)
plt.title('Interdependency of Sales,Profits and Discounts',fontsize=15)
plt.show()

# %% [markdown]
# ### <b>Conclusion</b>

# %% [markdown]
# Following are points where one can work to make more profit:
# <ul>
#     <li><b><u>Furniture sales should be limited</u></b>. More focus towards Technology and Office Supplies will help to earn more profit.</li>
#     <li><b><u>Shutting Down the "Tables and Book Cases" sales would be in favour of company</u></b> as it will decrease the loss suffered by company.</li>
#     <li><b>West & East</b> region are making more profit for us. Increasing the sales there would be preferable.</li>
#     <li>Marketing Campaign in <b>South & Central</b> would increase sales as well profit. </li>
#     <li><b>California & New York</b> are big asset for company.</li>
#     <li><b>Discounts are increasing Sales</b>, however increase in Discounts doesn't help in making more profit. It's time to<b> limit the Discount</b></li>
# </ul>
